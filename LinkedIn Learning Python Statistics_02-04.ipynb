# %%
import pandas as pd
import numpy as nmp

import matplotlib
import matplotlib.pyplot as plt

# %%
bb = pd.read_csv('billboard.csv')

# %%
bb.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# ...

# %%
bb.columns
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
# ...

# %%
plt.plot(bb.loc[0,'x1st.week':'x76th.week'])

# %%
plt.plot(range(1,77),bb.loc[0,'x1st.week':'x76th.week'])

# %%
bshort = bb[['artist.inverted', 'track', 'time','date.entered','x1st.week', 'x2nd.week', 'x3rd.week']]
bshort.head()
# Out:
#        artist.inverted                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  x1st.week  x2nd.week  x3rd.week
# 0   2000-09-23         78       63.0       49.0
# 1   2000-02-12         15        8.0        6.0
# 2   1999-10-23         71       48.0       43.0
# 3   2000-08-12         41       23.0       18.0
# 4   2000-08-05         57       47.0       45.0

# %%
bshort.columns=['artist','track','time','date.entered','wk1', 'wk2', 'wk3']
bshort.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  wk1   wk2   wk3
# 0   2000-09-23   78  63.0  49.0
# 1   2000-02-12   15   8.0   6.0
# 2   1999-10-23   71  48.0  43.0
# 3   2000-08-12   41  23.0  18.0
# 4   2000-08-05   57  47.0  45.0

# %%
dmelt = bshort.melt(['artist','track','time','date.entered'],['wk1', 'wk2', 'wk3'],'week','rank')
dmelt.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered week  rank
# 0   2000-09-23  wk1  78.0
# 1   2000-02-12  wk1  15.0
# 2   1999-10-23  wk1  71.0
# 3   2000-08-12  wk1  41.0
# 4   2000-08-05  wk1  57.0

# %%
dmelt.query('track == "Liar"')
# Out:
#       artist track  time date.entered week  rank
# 66   Profyle  Liar  3:57   2000-09-16    1  52.0
# 383  Profyle  Liar  3:57   2000-09-16    2  32.0
# 700  Profyle  Liar  3:57   2000-09-16    3  25.0

# %%
dmelt['week'] = dmelt['week'].apply(lambda s: int(s[2]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-1540faa4dce1> in <module>
# ----> 1 dmelt['week'] = dmelt['week'].apply(lambda s: int(s[2]))
#
# ~\miniconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-26-1540faa4dce1> in <lambda>(s)
# ----> 1 dmelt['week'] = dmelt['week'].apply(lambda s: int(s[2]))
#
# IndexError: string index out of range

# %%
dmelt['date.entered']=pd.to_datetime(dmelt['date.entered'])

# %%
dmelt['date'] = dmelt['date.entered']

# %%
dmelt.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered week  rank       date
# 0   2000-09-23    1  78.0 2000-09-23
# 1   2000-02-12    1  15.0 2000-02-12
# 2   1999-10-23    1  71.0 1999-10-23
# 3   2000-08-12    1  41.0 2000-08-12
# 4   2000-08-05    1  57.0 2000-08-05

# %%
type(dmelt['date'])
# Out:
# pandas.core.series.Series

# %%
dmelt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 951 entries, 0 to 950
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist        951 non-null    object
#  1   track         951 non-null    object
#  2   time          951 non-null    object
#  3   date.entered  951 non-null    datetime64[ns]
#  4   week          951 non-null    object
#  5   rank          936 non-null    float64
#  6   date          951 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 52.1+ KB

# %%
dmelt.drop(['date.entered'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-8b0d2b10cc29> in <module>
# ----> 1 dmelt.drop(['date.entered'])
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
dmelt.drop(['date.entered'], axis = 1, inplace = True)

# %%
dmelt.head(20)
# Out:
#                  artist                                  track  time week  \
# 0       Destiny's Child               Independent Women Part I  3:38    1
# 1               Santana                           Maria, Maria  4:18    1
# 2         Savage Garden                     I Knew I Loved You  4:07    1
# 3               Madonna                                  Music  3:45    1
# 4   Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38    1
# 5                 Janet                  Doesn't Really Matter  4:17    1
# 6       Destiny's Child                            Say My Name  4:31    1
# 7     Iglesias, Enrique                            Be With You  3:36    1
# 8                 Sisqo                             Incomplete  3:52    1
# 9              Lonestar                                 Amazed  4:25    1
# 10               N'Sync                       It's Gonna Be Me  3:10    1
# 11  Aguilera, Christina                      What A Girl Wants  3:18    1
# ...

# %%
bfinal = dmelt[['artist','track','time', 'date', 'week', 'rank']]

# %%
bfinal.sort_values(['artist', 'track'], inplace = True)
bfinal.head(20)
# Out:
#            artist                                              track  time  \
# 246         2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 563         2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 880         2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 287       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 604       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 921       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 24   3 Doors Down                                         Kryptonite  3:53
# 341  3 Doors Down                                         Kryptonite  3:53
# 658  3 Doors Down                                         Kryptonite  3:53
# 193  3 Doors Down                                              Loser  4:24
# 510  3 Doors Down                                              Loser  4:24
# ...

# %%
tracks = bfinal[['artist','track','time']].drop_duplicates()
tracks.head()
# Out:
#            artist                                              track  time
# 246         2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 287       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 24   3 Doors Down                                         Kryptonite  3:53
# 193  3 Doors Down                                              Loser  4:24
# 69       504 Boyz                                      Wobble Wobble  3:35

# %%
tracks.index.name ='id'
tracksid = tracks.reset_index()
tracksid.head()
# Out:
#     id        artist                                              track  time
# 0  246         2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 1  287       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 2   24  3 Doors Down                                         Kryptonite  3:53
# 3  193  3 Doors Down                                              Loser  4:24
# 4   69      504 Boyz                                      Wobble Wobble  3:35

# %%
tidy = pd.merge(tracksid, bfinal, on =['artist','track','time'])

# %%
tidy.head()
# Out:
#     id   artist                                              track  time  \
# 0  246    2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 1  246    2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 2  246    2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 3  287  2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 4  287  2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
#
#         date week  rank
# 0 2000-02-26    1  87.0
# 1 2000-02-26    2  82.0
# 2 2000-02-26    3  72.0
# 3 2000-09-02    1  91.0
# 4 2000-09-02    2  87.0

# %%
tidy.drop(['artist','track','time'], axis = 1)
# Out:
#     id       date week  rank
# 0  246 2000-02-26    1  87.0
# 1  246 2000-02-26    2  82.0
# 2  246 2000-02-26    3  72.0
# 3  287 2000-09-02    1  91.0
# 4  287 2000-09-02    2  87.0

# %%
2021 - tidy.date.dt.year
# Out:
# 0    21
# 1    21
# 2    21
# 3    21
# 4    21
# Name: date, dtype: int64

# %%
tidy[tidy.week ==1]['rank'].idxmin()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-8b47233a466c> in <module>
# ----> 1 tidy.loc[tidy[tidy.week ==1]['rank'].idxmin()]
#
# ~\miniconda3\lib\site-packages\pandas\core\series.py in idxmin(self, axis, skipna, *args, **kwargs)
#    2101         """
#    2102         skipna = nv.validate_argmin_with_skipna(skipna, args, kwargs)
# -> 2103         i = nanops.nanargmin(self._values, skipna=skipna)
#    2104         if i == -1:
#    2105             return np.nan
#
# ~\miniconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ...

# %%
tracksid.query('id == 1')
# Out:
#      id   artist         track  time
# 252   1  Santana  Maria, Maria  4:18
